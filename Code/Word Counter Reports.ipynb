# %%
# from pdfreader import SimplePDFViewer
import pandas as pd
import numpy as np
from natsort import index_natsorted
import os
import textract
import re

# %% [markdown]
# # Bulk analysis

# %% [markdown]
# This code iterates through a folder of PDFs (Deutsche Bahn annual accounting reports), and counts the appearances of particular terms in the documents.

# %%
# Code applied with the help of:
# https://www.geeksforgeeks.org/how-to-read-multiple-text-files-from-folder-in-python/
# https://stackoverflow.com/questions/50317483/count-the-total-number-of-words-in-a-pdf-document-using-python

# Change the directory
path = "../Dokumente/Publikationen DB/pdfs" # Select path with pdfs
os.chdir(path)

# %% [markdown]
# Below a dynamic script iterates through a folder with pdf files. The `regex` functions were tested in another cell below. The larger set of code here closely follows the logic of the files collected: reports from the Bahn. As a result, early reports are excluded, due to their poor quality.

# %%
master_df = pd.DataFrame(columns=['Datei', 'Anzahl_Worte', 'Verkehrswende', 'Digital','Nachhaltig',
                                  'Ökologie', 'Energie', 'Klima', 'Reform', 'Obsoleszenz', 'Verspätung', 'Wettbewerb'])

# Define conditions
verk = r'(?i)verkehrsw|mobilitätsw|verkehrsverl'
digi = r'(?i)digi'
nach = r'(?i)nachha|sustaina'
oeko = r'(?i)(?=(öko|umwelt|natur))(?!(ökonomi|naturgemäß|natürlich))'
spät = r'(?i)verpät|pünktl'
ener = r'(?i)energie|strom|solar|sonnenen|winde|strom|kohle|gas|erneuerbare|astroms'
klim = r'(?i)klima|co2|kohlenstoffdioxid|climate|carbon|treibhausg'
ref = r'(?i)reform|restruktur'
obso = r'(?i)obsoleszenz|repar|schaden|instandh|störung|instandse|stillstand|baustell|sani|renovi|mainten|wiederaufb|ausbess|veraltet'
wettbew = r'(?i)wettbe|konkurr|marktfü'

# Define masterframe
def analyse_text(file_path): 
    '''
    This code is used to apply regex search strings to the texts. It has the key operator `text`, which is why additional functions are called in here.
    The functions prepares to iterate through all PDF files in a given folder and pulls out matching word groups and their counts.
    '''
    with open(file_path, 'r') as f:
        text = textract.process(file_path)
        text = text.decode()
                                  
        # use regex calls for each file
        result_v = re.findall(verk, text, re.MULTILINE) # Verkehrswende
        results_v = len(result_v)
        
        result_d = re.findall(digi, text, re.MULTILINE) # Digitalisierung
        results_d = len(result_d) 

        result_n = re.findall(nach, text, re.MULTILINE) # Nachhaltigkeit
        results_n = len(result_n)                                   
                                  
        result_o = re.findall(oeko, text, re.MULTILINE) # Ökologie
        results_o = len(result_o)  

        result_s = re.findall(spät, text, re.MULTILINE) # IT
        results_s = len(result_s) 

        result_e = re.findall(ener, text, re.MULTILINE) # Energie
        results_e = len(result_e)                                   

        result_k = re.findall(klim, text, re.MULTILINE) # Klima
        results_k = len(result_k)        
        
        result_r = re.findall(ref, text, re.MULTILINE) # Reform
        results_r = len(result_r)
        
        result_ob = re.findall(obso, text, re.MULTILINE) # Obsoleszenz
        results_ob = len(result_ob)
        
        result_w = re.findall(wettbew, text, re.MULTILINE) # Wettbewerb
        results_w = len(result_w)
        
        # Count words in each pdf
        wordfreq = len(re.findall(r'\w+', text))
        
        # Pull into the master dataframe                          
        global master_df
        master_df_list = [{'Datei': fl,
                                      'Anzahl_Worte': wordfreq,
                                      'Verkehrswende': results_v,
                                      'Digital': results_d, 
                                      'Nachhaltig': results_n, 
                                      'Ökologie': results_o,
                                      'Energie': results_e,
                                      'Klima': results_k,
                                      'Reform': results_r,
                                      'Obsoleszenz': results_ob,
                                      'Verspätung': results_s,
                                      'Wettbewerb': results_w}] #, ignore_index=True]
        master_df = pd.concat([master_df, pd.DataFrame.from_records(master_df_list)])
        
        # print('Häufigkeit Wettbewerbsfähigkeit: ',results, 'Dokument: ', fl) 
        
# Start script
for file in os.listdir():
    '''
    The script iterates through a folder and saves/prints the results for the above regex search for each file.
    '''
    # Check whether file is in text format or not
    if file.endswith(".pdf"):
        file_path = f"{path}/{file}"
        fl = f"{file}"           
        # call read text file function
        analyse_text(file_path)

# show resulting dataframe and sort by year
master_df.sort_values(
    by='Datei',
    key=lambda x: np.argsort(index_natsorted(master_df['Datei'])),
    ascending=True
)
# Out:
#              Datei Anzahl_Worte Verkehrswende Digital Nachhaltig Ökologie  \
# 0   5-DB_GB_98.pdf        28922             4       1          6        9
# 0   6-DB_GB_99.pdf        33883             2       2          5       37
# 0   7-DB_GB_00.pdf        37469             2       3          8       41
# 0   8-DB_GB_01.pdf        38688             1       6          7       42
# 0   9-DB_GB_02.pdf        67287             6       4         23       49
# 0  10-DB_GB_03.pdf        67830             6       4         18       41
# 0  11-DB_GB_04.pdf        84650             9       6         25       52
# 0  12-DB_GB_05.pdf        82478             3       1         20       56
# 0  13-DB_GB_06.pdf        66966             4       1         17       42
# 0  14-DB_GB_07.pdf        90083             3       1         36       50
# 0  15-DB_GB_08.pdf        87897             3       1         43       47
# 0  16-DB_GB_09.pdf       102424             8       1         58       76
# 0  17-DB_GB_10.pdf       117598             4       1         49       69
# 0  18-DB_GB_11.pdf       134571             8       3         90      118
# 0  19-DB_GB_12.pdf       154488             4       2         92      282
# 0  20-DB_GB_13.pdf       164070             8       6         77      197
# 0  21-DB_IB_14.pdf       166342             7      61        131      261
# 0  22-DB_IB_15.pdf       171343            12     111        118      203
# 0  23-DB_IB_16.pdf       158827            10     151        137      211
# 0  24-DB_IB-17.pdf       156714            12     295        135      256
# 0  25-DB_IB_18.pdf       158535            15     257        131      219
# 0  26-DB_IB-19.pdf       155573            36     234        401      212
# 0   27-DB_IB20.pdf       166766            34     249        452      203
#
#   Energie Klima Reform Obsoleszenz Verspätung Wettbewerb
# 0      38     0     29          18         14         30
# 0      35     1     18          22          5         32
# 0      54     8     28          51          4         53
# 0      67    16     22          75          1         50
# 0     101    16     27          95          3         93
# 0     105    24     46         106         11         92
# 0     138    17     34          88         13        105
# 0     139    16     15          60          5        120
# 0     133    15      9          55          5         70
# 0     167    15      9          59          6         91
# 0     193    37     11          81          9         85
# 0     227    30     14          84          6         97
# 0     255    23     10          85          7         79
# 0     531    38     19          83         21        105
# 0     406    33     29          91         31        121
# 0     503    30     26         146         51        139
# 0     656    66     27         168         68        129
# 0     554    71     22         159         90        170
# 0     635   106     18         181         76        138
# 0     596   156     27         238        109        110
# 0     612   146     24         215        121         88
# 0     585   174     20         183         76         87
# 0     602   189     13         173         90         66

# %% [markdown]
# The original dataframe has the files as dataframe columns. In this case, however, the files can be equated with years, because they represent yearly reports. Hence simplification.

# %%
df=master_df.copy()
df=df.sort_values(
    by='Datei',
    key=lambda x: np.argsort(index_natsorted(master_df['Datei'])),
    ascending=True
)

df = df.reset_index(drop=True)
# df = df.drop(['index'], axis=1)
df.head()
# Out:
#             Datei Anzahl_Worte Verkehrswende Digital Nachhaltig Ökologie  \
# 0  5-DB_GB_98.pdf        28922             4       1          6        9
# 1  6-DB_GB_99.pdf        33883             2       2          5       37
# 2  7-DB_GB_00.pdf        37469             2       3          8       41
# 3  8-DB_GB_01.pdf        38688             1       6          7       42
# 4  9-DB_GB_02.pdf        67287             6       4         23       49
#
#   Energie Klima Reform Obsoleszenz Verspätung Wettbewerb
# 0      38     0     29          18         14         30
# 1      35     1     18          22          5         32
# 2      54     8     28          51          4         53
# 3      67    16     22          75          1         50
# 4     101    16     27          95          3         93

# %%
# Rename file column
df = df.rename(columns={'Datei': 'Jahr'})

# Rename column content
df['Jahr'] = df['Jahr'].replace(['5-DB_GB_98.pdf',
                                 '6-DB_GB_99.pdf',
                                 '7-DB_GB_00.pdf',
                                 '8-DB_GB_01.pdf',
                                 '9-DB_GB_02.pdf',
                                 '10-DB_GB_03.pdf',
                                 '11-DB_GB_04.pdf',
                                 '12-DB_GB_05.pdf',
                                 '13-DB_GB_06.pdf',
                                 '14-DB_GB_07.pdf',
                                 '15-DB_GB_08.pdf',
                                 '16-DB_GB_09.pdf',
                                 '17-DB_GB_10.pdf',
                                 '18-DB_GB_11.pdf',
                                 '19-DB_GB_12.pdf',
                                 '20-DB_GB_13.pdf',
                                 '21-DB_IB_14.pdf',
                                 '22-DB_IB_15.pdf',
                                 '23-DB_IB_16.pdf',
                                 '24-DB_IB-17.pdf',
                                 '25-DB_IB_18.pdf',
                                 '26-DB_IB-19.pdf',
                                 '27-DB_IB20.pdf',
                                 ], 
                                 ['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
                                 '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])     
# df.sort_values(by='Jahr', ascending=False)
df
# Out:
#     Jahr Anzahl_Worte Verkehrswende Digital Nachhaltig Ökologie Energie Klima  \
# 0   1998        28922             4       1          6        9      38     0
# 1   1999        33883             2       2          5       37      35     1
# 2   2000        37469             2       3          8       41      54     8
# 3   2001        38688             1       6          7       42      67    16
# 4   2002        67287             6       4         23       49     101    16
# 5   2003        67830             6       4         18       41     105    24
# 6   2004        84650             9       6         25       52     138    17
# 7   2005        82478             3       1         20       56     139    16
# 8   2006        66966             4       1         17       42     133    15
# 9   2007        90083             3       1         36       50     167    15
# 10  2008        87897             3       1         43       47     193    37
# 11  2009       102424             8       1         58       76     227    30
# 12  2010       117598             4       1         49       69     255    23
# 13  2011       134571             8       3         90      118     531    38
# 14  2012       154488             4       2         92      282     406    33
# 15  2013       164070             8       6         77      197     503    30
# 16  2014       166342             7      61        131      261     656    66
# 17  2015       171343            12     111        118      203     554    71
# 18  2016       158827            10     151        137      211     635   106
# 19  2017       156714            12     295        135      256     596   156
# 20  2018       158535            15     257        131      219     612   146
# 21  2019       155573            36     234        401      212     585   174
# 22  2020       166766            34     249        452      203     602   189
#
#    Reform Obsoleszenz Verspätung Wettbewerb
# 0      29          18         14         30
# 1      18          22          5         32
# 2      28          51          4         53
# 3      22          75          1         50
# 4      27          95          3         93
# 5      46         106         11         92
# 6      34          88         13        105
# 7      15          60          5        120
# 8       9          55          5         70
# 9       9          59          6         91
# 10     11          81          9         85
# 11     14          84          6         97
# 12     10          85          7         79
# 13     19          83         21        105
# 14     29          91         31        121
# 15     26         146         51        139
# 16     27         168         68        129
# 17     22         159         90        170
# 18     18         181         76        138
# 19     27         238        109        110
# 20     24         215        121         88
# 21     20         183         76         87
# 22     13         173         90         66

# %% [markdown]
# # Making Sense of the data distribution.

# %% [markdown]
# An important issue of the data is that the reports are of different length. We can clearly see the degrees to which a topic matters, but how much does it matter that a report gets longer? There is not a clear relationship, but looking at the data from different perspectives helps.

# %% [markdown]
# The first dataframe presents a bar char for each column where the chart indicates the relative size of each value compared to the hightest value in the column. Note that the bars only indicate the highest value for each column.

# %%
# Export to csv (first try from 2021)
df.to_csv('../6- Betriebsstörungen und SFB Siegen/Forschung/Dokumente/Publikationen DB/pdfs/frequency_count.csv')
# Out:
# <style  type="text/css" >
# #T_791a0_row0_col1,#T_791a0_row0_col2,#T_791a0_row0_col4,#T_791a0_row0_col6,#T_791a0_row0_col7,#T_791a0_row1_col3,#T_791a0_row7_col2,#T_791a0_row8_col2,#T_791a0_row9_col2,#T_791a0_row10_col2,#T_791a0_row11_col2,#T_791a0_row12_col2,#T_791a0_row23_col5,#T_791a0_row23_col8{
#             width:  10em;
#              height:  80%;
#         }#T_791a0_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 0.2%, transparent 0.2%);
#         }#T_791a0_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 66.7%, transparent 66.7%);
#         }#T_791a0_row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 14.5%, transparent 14.5%);
#         }#T_791a0_row1_col1,#T_791a0_row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 3.5%, transparent 3.5%);
#         }#T_791a0_row1_col2,#T_791a0_row13_col2,#T_791a0_row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 0.4%, transparent 0.4%);
#         }#T_791a0_row1_col4,#T_791a0_row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 7.2%, transparent 7.2%);
#         }#T_791a0_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 33.3%, transparent 33.3%);
#         }#T_791a0_row1_col6,#T_791a0_row6_col6,#T_791a0_row9_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 11.3%, transparent 11.3%);
#         }#T_791a0_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 13.6%, transparent 13.6%);
#         }#T_791a0_row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 13.1%, transparent 13.1%);
#         }#T_791a0_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.0%, transparent 6.0%);
#         }#T_791a0_row2_col2,#T_791a0_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 0.7%, transparent 0.7%);
#         }#T_791a0_row2_col4,#T_791a0_row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 5.0%, transparent 5.0%);
#         }#T_791a0_row2_col5,#T_791a0_row9_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 53.8%, transparent 53.8%);
#         }#T_791a0_row2_col6,#T_791a0_row5_col6,#T_791a0_row23_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 5.7%, transparent 5.7%);
#         }#T_791a0_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 17.1%, transparent 17.1%);
#         }#T_791a0_row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 29.7%, transparent 29.7%);
#         }#T_791a0_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.9%, transparent 6.9%);
#         }#T_791a0_row3_col2,#T_791a0_row6_col2,#T_791a0_row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 1.8%, transparent 1.8%);
#         }#T_791a0_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 0.5%, transparent 0.5%);
#         }#T_791a0_row3_col4,#T_791a0_row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 5.8%, transparent 5.8%);
#         }#T_791a0_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 41.0%, transparent 41.0%);
#         }#T_791a0_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 7.5%, transparent 7.5%);
#         }#T_791a0_row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 16.4%, transparent 16.4%);
#         }#T_791a0_row3_col8,#T_791a0_row17_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 25.5%, transparent 25.5%);
#         }#T_791a0_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 26.9%, transparent 26.9%);
#         }#T_791a0_row4_col2,#T_791a0_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 1.1%, transparent 1.1%);
#         }#T_791a0_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 4.2%, transparent 4.2%);
#         }#T_791a0_row4_col4,#T_791a0_row10_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.5%, transparent 6.5%);
#         }#T_791a0_row4_col5,#T_791a0_row15_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 38.5%, transparent 38.5%);
#         }#T_791a0_row4_col6,#T_791a0_row8_col6,#T_791a0_row10_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 13.2%, transparent 13.2%);
#         }#T_791a0_row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 18.6%, transparent 18.6%);
#         }#T_791a0_row4_col8,#T_791a0_row5_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 55.2%, transparent 55.2%);
#         }#T_791a0_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 27.3%, transparent 27.3%);
#         }#T_791a0_row5_col3,#T_791a0_row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 2.8%, transparent 2.8%);
#         }#T_791a0_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 3.6%, transparent 3.6%);
#         }#T_791a0_row5_col5,#T_791a0_row14_col4,#T_791a0_row16_col6,#T_791a0_row16_col7,#T_791a0_row17_col1,#T_791a0_row17_col8,#T_791a0_row19_col2,#T_791a0_row22_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 100.0%, transparent 100.0%);
#         }#T_791a0_row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 14.3%, transparent 14.3%);
#         }#T_791a0_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 39.1%, transparent 39.1%);
#         }#T_791a0_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 4.6%, transparent 4.6%);
#         }#T_791a0_row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 59.0%, transparent 59.0%);
#         }#T_791a0_row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 23.6%, transparent 23.6%);
#         }#T_791a0_row6_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 64.1%, transparent 64.1%);
#         }#T_791a0_row7_col1{
#             width:  10em;

# %%
# Export to csv (update from 2022)
df.to_csv('../Dokumente/Publikationen DB/pdfs/frequency_count_update_2022_.csv')

# %% [markdown]
# The next dataframe calculates the values of a column relative to the length of the entire PDF.

# %%
# Original test from 2021
# Note that the values are not true to counting but based on rounding
df_relative = df.copy()
df_relative['Digitalisierung'] = ((100000 * df_relative['Digitalisierung']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Nachhaltigkeit'] = ((100000 * df_relative['Nachhaltigkeit']) / df_relative['Anzahl_Worte']).astype(int)
#df_relative['Ökologie'] = ((100000 * df_relative['Ökologie']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Reform'] = ((100000 * df_relative['Reform']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Ressourcen'] = ((100000 * df_relative['Ressourcen']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Umwelt'] = ((100000 * df_relative['Umwelt']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Wettbewerb'] = ((100000 * df_relative['Wettbewerb']) / df_relative['Anzahl_Worte']).astype(int)
df_relative
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ressourcen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 9>()
#       7 #df_relative['Ökologie'] = ((100000 * df_relative['Ökologie']) / df_relative['Anzahl_Worte']).astype(int)
#       8 df_relative['Reform'] = ((100000 * df_relative['Reform']) / df_relative['Anzahl_Worte']).astype(int)
# ----> 9 df_relative['Ressourcen'] = ((100000 * df_relative['Ressourcen']) / df_relative['Anzahl_Worte']).astype(int)
#      10 df_relative['Umwelt'] = ((100000 * df_relative['Umwelt']) / df_relative['Anzahl_Worte']).astype(int)
#      11 df_relative['Wettbewerb'] = ((100000 * df_relative['Wettbewerb']) / df_relative['Anzahl_Worte']).astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Ressourcen'

# %%
# Update from 2022
# Note that the values are not true to counting but based on rounding
df_relative = df.copy()
df_relative['Verkehrswende'] = ((100000 * df_relative['Verkehrswende']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Digital'] = ((100000 * df_relative['Digital']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Nachhaltig'] = ((100000 * df_relative['Nachhaltig']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Ökologie'] = ((100000 * df_relative['Ökologie']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Verspätung'] = ((100000 * df_relative['Verspätung']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Energie'] = ((100000 * df_relative['Energie']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Klima'] = ((100000 * df_relative['Klima']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Reform'] = ((100000 * df_relative['Reform']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Obsoleszenz'] = ((100000 * df_relative['Obsoleszenz']) / df_relative['Anzahl_Worte']).astype(int)
df_relative['Wettbewerb'] = ((100000 * df_relative['Wettbewerb']) / df_relative['Anzahl_Worte']).astype(int)
df_relative
# Out:
#     Jahr Anzahl_Worte  Verkehrswende  Digital  Nachhaltig  Ökologie  Energie  \
# 0   1998        28922             13        3          20        31      131
# 1   1999        33883              5        5          14       109      103
# 2   2000        37469              5        8          21       109      144
# 3   2001        38688              2       15          18       108      173
# 4   2002        67287              8        5          34        72      150
# 5   2003        67830              8        5          26        60      154
# 6   2004        84650             10        7          29        61      163
# 7   2005        82478              3        1          24        67      168
# 8   2006        66966              5        1          25        62      198
# 9   2007        90083              3        1          39        55      185
# 10  2008        87897              3        1          48        53      219
# 11  2009       102424              7        0          56        74      221
# 12  2010       117598              3        0          41        58      216
# 13  2011       134571              5        2          66        87      394
# 14  2012       154488              2        1          59       182      262
# 15  2013       164070              4        3          46       120      306
# 16  2014       166342              4       36          78       156      394
# 17  2015       171343              7       64          68       118      323
# 18  2016       158827              6       95          86       132      399
# 19  2017       156714              7      188          86       163      380
# 20  2018       158535              9      162          82       138      386
# 21  2019       155573             23      150         257       136      376
# 22  2020       166766             20      149         271       121      360
#
#     Klima  Reform  Obsoleszenz  Verspätung  Wettbewerb
# 0       0     100           62          48         103
# 1       2      53           64          14          94
# 2      21      74          136          10         141
# 3      41      56          193           2         129
# 4      23      40          141           4         138
# 5      35      67          156          16         135
# 6      20      40          103          15         124
# 7      19      18           72           6         145
# 8      22      13           82           7         104
# 9      16       9           65           6         101
# 10     42      12           92          10          96
# 11     29      13           82           5          94
# 12     19       8           72           5          67
# 13     28      14           61          15          78
# 14     21      18           58          20          78
# 15     18      15           88          31          84
# 16     39      16          100          40          77
# 17     41      12           92          52          99
# 18     66      11          113          47          86
# 19     99      17          151          69          70
# 20     92      15          135          76          55
# 21    111      12          117          48          55
# 22    113       7          103          53          39

# %%
df_relative.to_csv('../Dokumente/Publikationen DB/pdfs/frequency_count_relative_2022_.csv') # saved with Ökologie

# %%
df_relative.style.bar(subset=['Anzahl_Worte', 'Digitalisierung', 'Nachhaltigkeit', 'Ökologie', 'Reform', 'Ressourcen', 'Umwelt', 'Wettbewerb'], color=['#a1d99b'])
# Out:
# <style  type="text/css" >
# #T_798a9_row0_col1,#T_798a9_row0_col4,#T_798a9_row0_col6,#T_798a9_row0_col7,#T_798a9_row1_col3,#T_798a9_row11_col2,#T_798a9_row12_col2,#T_798a9_row22_col5,#T_798a9_row23_col8{
#             width:  10em;
#              height:  80%;
#         }#T_798a9_row0_col2,#T_798a9_row3_col3,#T_798a9_row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 1.6%, transparent 1.6%);
#         }#T_798a9_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 2.4%, transparent 2.4%);
#         }#T_798a9_row0_col5,#T_798a9_row2_col8,#T_798a9_row14_col4,#T_798a9_row16_col6,#T_798a9_row16_col7,#T_798a9_row17_col1,#T_798a9_row19_col2,#T_798a9_row22_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 100.0%, transparent 100.0%);
#         }#T_798a9_row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 69.7%, transparent 69.7%);
#         }#T_798a9_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 3.5%, transparent 3.5%);
#         }#T_798a9_row1_col2,#T_798a9_row4_col2,#T_798a9_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 2.7%, transparent 2.7%);
#         }#T_798a9_row1_col4,#T_798a9_row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 33.3%, transparent 33.3%);
#         }#T_798a9_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 43.5%, transparent 43.5%);
#         }#T_798a9_row1_col6,#T_798a9_row10_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 63.0%, transparent 63.0%);
#         }#T_798a9_row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 81.2%, transparent 81.2%);
#         }#T_798a9_row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 52.1%, transparent 52.1%);
#         }#T_798a9_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.0%, transparent 6.0%);
#         }#T_798a9_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 4.4%, transparent 4.4%);
#         }#T_798a9_row2_col3,#T_798a9_row23_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 2.8%, transparent 2.8%);
#         }#T_798a9_row2_col4,#T_798a9_row11_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 20.7%, transparent 20.7%);
#         }#T_798a9_row2_col5,#T_798a9_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 62.0%, transparent 62.0%);
#         }#T_798a9_row2_col6,#T_798a9_row4_col6,#T_798a9_row8_col6,#T_798a9_row20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 25.9%, transparent 25.9%);
#         }#T_798a9_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 90.6%, transparent 90.6%);
#         }#T_798a9_row3_col1,#T_798a9_row6_col4,#T_798a9_row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.9%, transparent 6.9%);
#         }#T_798a9_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 8.2%, transparent 8.2%);
#         }#T_798a9_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 23.0%, transparent 23.0%);
#         }#T_798a9_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 45.7%, transparent 45.7%);
#         }#T_798a9_row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 82.8%, transparent 82.8%);
#         }#T_798a9_row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 83.2%, transparent 83.2%);
#         }#T_798a9_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 26.9%, transparent 26.9%);
#         }#T_798a9_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 8.1%, transparent 8.1%);
#         }#T_798a9_row4_col4,#T_798a9_row13_col4,#T_798a9_row15_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 12.6%, transparent 12.6%);
#         }#T_798a9_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 23.9%, transparent 23.9%);
#         }#T_798a9_row4_col7,#T_798a9_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 39.1%, transparent 39.1%);
#         }#T_798a9_row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 95.0%, transparent 95.0%);
#         }#T_798a9_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 27.3%, transparent 27.3%);
#         }#T_798a9_row5_col3,#T_798a9_row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 4.5%, transparent 4.5%);
#         }#T_798a9_row5_col4,#T_798a9_row23_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 5.7%, transparent 5.7%);
#         }#T_798a9_row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 3.7%, transparent 3.7%);
#         }#T_798a9_row5_col7,#T_798a9_row10_col7,#T_798a9_row12_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 23.4%, transparent 23.4%);
#         }#T_798a9_row5_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 94.1%, transparent 94.1%);
#         }#T_798a9_row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 3.8%, transparent 3.8%);
#         }#T_798a9_row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 6.1%, transparent 6.1%);
#         }#T_798a9_row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 29.3%, transparent 29.3%);
#         }#T_798a9_row6_col6,#T_798a9_row12_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 11.1%, transparent 11.1%);
#         }#T_798a9_row6_col7,#T_798a9_row8_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 35.9%, transparent 35.9%);
#         }#T_798a9_row6_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 85.7%, transparent 85.7%);
#         }#T_798a9_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1d99b 37.6%, transparent 37.6%);
#         }#T_798a9_row7_col2,#T_798a9_row8_col2,#T_798a9_row9_col2,#T_798a9_row10_col2,#T_798a9_row13_col2,#T_798a9_row14_col2{

# %% [markdown]
# The conclusion: Digital and sustinability matters have become significantly more important during the past decade, with the programme Starke Schiene in 2019 really making a difference. There is also a notable decline of matters of competition, at least in its traditional phrasing, although it remainds relevant. Besides, note that ecology (framed as "Umwelt") used to be a relevant topic during the late 1990s and early 2000s, but then vanished for roughly a decade and then got "overtaken" by ecology and then sustainability in particular. "Ressources" are rather ambigious and are not very helpful, although it can become a relatively important term in certain sectors.

# %% [markdown]
# # Count words: Single code for testing

# %%
# define search string
# wettbew = re.findall(r'\s(?i)wettbew', text, re.MULTILINE) # Sucht nach allen strings "wettbe", case insensitive, mit whitespace davor

# Testet conditions
verk = r'(?i)verkehrsw|mobilitätsw|verkehrsverl
digi = r'(?i)digit'
nach = r'(?i)nachha|sustaina'
oeko = r'(?i)öko' # (?i)öko[^n] war nur bedingt hilfreich
ener = r'(?i)energie|strom|kohle|gas|erneuerbare'
klim = r'(?i)klima|co2|kohlenstoffdioxid|climate|carbon|treibhausg'
ref = r'(?i)reform'
obso = r'(?i)obsoleszenz|repar|schaden|instandh|stillstand|baustell|zuverlässig'
wettbew = r'(?i)wettbe|konkurr|rentab|gewinn|profit|wirtschaftlich'


# Nach Tests auf Grund niedriger Statistiken wenig aussagekräftig: standard, investi, ressourcen, IT-

# %%
# Parsing with textract
text_test = textract.process("../Dokumente/Publikationen DB/pdfs/22-DB_IB_15.pdf")
text_test = text_test.decode() # Transform bytes to string

# Search for words
test = re.findall(r'(?i)verpät|pünktl', text_test, re.MULTILINE) # Sucht nach allen strings, case insensitive, mit whitespace davor

# Check results
print(len(test))
# Out:
# 90
